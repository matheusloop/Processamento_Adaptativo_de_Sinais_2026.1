# %% [markdown]
# # Reprodução Fiel da AIRMLP7-1500

# %%
# Manipulação de dados
import numpy as np
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt

# Construção e treinamento do modelo
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Input, Dense, BatchNormalization
from keras.optimizers import Adam

# Avaliação e divisão dos dados
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

# Configurações dos gráficos
plt.rcParams.update({'font.size': 14})

# %%
def createWindows(df, windowSize):

    # Separa as variáveis de entrada e a variável alvo
    X = df.drop(columns=['valid_at', 'valore_originale', 'pm2p5_y']).values
    y = df['pm2p5_y'].values

    X_sep = []
    y_sep = []

    # Cria janelas deslizantes nos dados
    for i in range(len(X) - windowSize + 1):

        # Obtém e achata a janela de características
        janela_features = X[i : i + windowSize].flatten()
        X_sep.append(janela_features)

        # Define como alvo o último valor da janela
        alvo = y[i + windowSize - 1]
        y_sep.append(alvo)

    # Converte as listas em DataFrames
    X_final = pd.DataFrame(np.array(X_sep))
    y_final = pd.DataFrame(np.array(y_sep))

    return X_final, y_final

# %% [markdown]
# ## Configurações da entrada e da camada oculta

# %%
totalFeatures = 6
windowSize    = 20
num_hidden    = 1500

# %% [markdown]
# ## Dados e pré-processamento

# %%
# Carrega os dados
ari_Mar_01 = pd.read_csv('Dados/ari-1727.csv')[::-1].reset_index(drop=True)
ari_Mar_02 = pd.read_csv('Dados/ari-1952.csv')[::-1].reset_index(drop=True)
ari_Mar_03 = pd.read_csv('Dados/ari-1953.csv')[::-1].reset_index(drop=True)
ari_Oct_01 = pd.read_csv('Dados/ari-1885.csv')[::-1].reset_index(drop=True)
ari_Oct_02 = pd.read_csv('Dados/ari-2049.csv')[::-1].reset_index(drop=True)
rf_01      = pd.read_csv('Dados/rf_1.csv')
rf_02      = pd.read_csv('Dados/rf_2.csv')

# Remove valores ausentes
ari_Mar_01.dropna(inplace=True)
ari_Mar_02.dropna(inplace=True)
ari_Mar_03.dropna(inplace=True)
ari_Oct_01.dropna(inplace=True)
ari_Oct_02.dropna(inplace=True)
rf_01.dropna(inplace=True)
rf_02.dropna(inplace=True)

# Converte a coluna de data para datetime
ari_Mar_01['valid_at'] = pd.to_datetime(ari_Mar_01['valid_at'])
ari_Mar_02['valid_at'] = pd.to_datetime(ari_Mar_02['valid_at'])
ari_Mar_03['valid_at'] = pd.to_datetime(ari_Mar_03['valid_at'])
ari_Oct_01['valid_at'] = pd.to_datetime(ari_Oct_01['valid_at'])
ari_Oct_02['valid_at'] = pd.to_datetime(ari_Oct_02['valid_at'])
rf_01['valid_at'] = pd.to_datetime(rf_01['valid_at'])
rf_02['valid_at'] = pd.to_datetime(rf_02['valid_at'])

# Ajusta os dados para o mesmo fuso horário
rf_01['valid_at'] = rf_01['valid_at'] - pd.Timedelta(hours=1)
rf_02['valid_at'] = rf_02['valid_at'] - pd.Timedelta(hours=1)

# Arredonda os horários para intervalos de uma hora
ari_Mar_01["valid_at"] = ari_Mar_01["valid_at"].dt.round("h")
ari_Mar_02["valid_at"] = ari_Mar_02["valid_at"].dt.round("h")
ari_Mar_03["valid_at"] = ari_Mar_03["valid_at"].dt.round("h")
ari_Oct_01["valid_at"] = ari_Oct_01["valid_at"].dt.round("h")
ari_Oct_02["valid_at"] = ari_Oct_02["valid_at"].dt.round("h")
rf_01["valid_at"] = rf_01["valid_at"].dt.round("h")
rf_02["valid_at"] = rf_02["valid_at"].dt.round("h")

# Combina os dados das estações ARI e RF
Data_Mar_01 = pd.merge(ari_Mar_01, rf_01, on='valid_at', how='inner')
Data_Mar_02 = pd.merge(ari_Mar_02, rf_01, on='valid_at', how='inner')
Data_Mar_03 = pd.merge(ari_Mar_03, rf_01, on='valid_at', how='inner')
Data_Oct_01 = pd.merge(ari_Oct_01, rf_02, on='valid_at', how='inner')
Data_Oct_02 = pd.merge(ari_Oct_02, rf_02, on='valid_at', how='inner')

# Criando as janelas de dados para cada DataFrame
X_Mar_01, y_Mar_01 = createWindows(Data_Mar_01, windowSize)
X_Mar_02, y_Mar_02 = createWindows(Data_Mar_02, windowSize)
X_Mar_03, y_Mar_03 = createWindows(Data_Mar_03, windowSize)
X_Oct_01, y_Oct_01 = createWindows(Data_Oct_01, windowSize)
X_Oct_02, y_Oct_02 = createWindows(Data_Oct_02, windowSize)

# Concatenando os conjuntos de features (X) e alvos (y) de todos os DataFrames
X = pd.concat([X_Mar_01, X_Mar_02, X_Mar_03, X_Oct_01, X_Oct_02], ignore_index=True)
y = pd.concat([y_Mar_01, y_Mar_02, y_Mar_03, y_Oct_01, y_Oct_02], ignore_index=True)

# Dividindo os dados em conjuntos de treino, validação e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=42)

# Ordenando os dados
X_train.sort_index(inplace=True)
X_test .sort_index(inplace=True)

y_train.sort_index(inplace=True)
y_test .sort_index(inplace=True)

# %% [markdown]
# ## Modelo da AirMLP7-1500

# %%
# Define a arquitetura da rede neural
model = Sequential()

model.add(Input(shape=(totalFeatures * windowSize,)))
model.add(BatchNormalization())
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(num_hidden, activation='relu'))
model.add(Dense(1))

# Exibe o resumo da arquitetura
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 120)            │           480 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1500)           │       181,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1500)           │     2,251,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1500)           │     2,251,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1500)           │     2,251,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1500)           │     2,251,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1500)           │     2,251,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │         1,501 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,440,981 (43.64 MB)
#  Trainable params: 11,440,741 (43.64 MB)
#  Non-trainable params: 240 (960.00 B)

# %%
# Compila o modelo
model.compile(
    loss='mean_absolute_error',
    optimizer=Adam(learning_rate=5e-5)
)

# Treina o modelo
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=200,
    batch_size=64,
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 17s 73ms/step - loss: 11.2944 - val_loss: 150.1813
# Epoch 2/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - loss: 8.6588 - val_loss: 11.0117
# Epoch 3/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 7.8141 - val_loss: 7.7792
# Epoch 4/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - loss: 7.0742 - val_loss: 6.8114
# Epoch 5/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - loss: 6.7084 - val_loss: 7.5937
# Epoch 6/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - loss: 6.3619 - val_loss: 6.3755
# Epoch 7/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - loss: 6.0630 - val_loss: 6.2481
# Epoch 8/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 5.9385 - val_loss: 5.5114
# Epoch 9/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 5.6955 - val_loss: 5.3559
# Epoch 10/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - loss: 5.4999 - val_loss: 5.2901
# Epoch 11/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 5.3431 - val_loss: 5.7849
# Epoch 12/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - loss: 5.1939 - val_loss: 5.5101
# Epoch 13/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 4.9974 - val_loss: 4.9354
# Epoch 14/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 4.8384 - val_loss: 4.7814
# Epoch 15/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 4.8195 - val_loss: 4.6286
# Epoch 16/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 4.6805 - val_loss: 4.9316
# Epoch 17/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 4.4815 - val_loss: 4.5486
# Epoch 18/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - loss: 4.3441 - val_loss: 4.6653
# Epoch 19/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - loss: 4.2644 - val_loss: 4.7103
# Epoch 20/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 4.2201 - val_loss: 4.4640
# Epoch 21/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 4.1231 - val_loss: 4.3808
# Epoch 22/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - loss: 3.9622 - val_loss: 4.2827
# Epoch 23/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 3.9435 - val_loss: 4.8617
# Epoch 24/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.7654 - val_loss: 4.1670
# Epoch 25/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - loss: 3.7413 - val_loss: 4.2622
# Epoch 26/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.6826 - val_loss: 4.2108
# Epoch 27/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.6438 - val_loss: 4.0901
# Epoch 28/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.6356 - val_loss: 3.9425
# Epoch 29/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.5527 - val_loss: 4.0947
# Epoch 30/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.5136 - val_loss: 4.0346
# Epoch 31/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.4087 - val_loss: 3.9003
# Epoch 32/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.2875 - val_loss: 3.9462
# Epoch 33/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.2495 - val_loss: 3.7592
# Epoch 34/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.3800 - val_loss: 3.8985
# Epoch 35/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.2542 - val_loss: 4.0869
# Epoch 36/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.1911 - val_loss: 3.7680
# Epoch 37/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 3.1765 - val_loss: 4.0178
# Epoch 38/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 3.1141 - val_loss: 3.8055
# Epoch 39/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 3.0928 - val_loss: 3.6015
# Epoch 40/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 3.0075 - val_loss: 3.6397
# Epoch 41/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.9524 - val_loss: 3.6742
# Epoch 42/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.9881 - val_loss: 3.6112
# Epoch 43/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.8845 - val_loss: 3.8594
# Epoch 44/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.9266 - val_loss: 3.5500
# Epoch 45/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.9096 - val_loss: 3.7188
# Epoch 46/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.9439 - val_loss: 3.7094
# Epoch 47/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.8289 - val_loss: 3.5080
# Epoch 48/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.7677 - val_loss: 3.4784
# Epoch 49/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.7149 - val_loss: 3.6432
# Epoch 50/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.6823 - val_loss: 3.8775
# Epoch 51/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.7303 - val_loss: 3.4084
# Epoch 52/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.6950 - val_loss: 3.8767
# Epoch 53/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.7273 - val_loss: 3.5314
# Epoch 54/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.6185 - val_loss: 3.4861
# Epoch 55/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.5698 - val_loss: 3.3229
# Epoch 56/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.5443 - val_loss: 3.4815
# Epoch 57/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.5774 - val_loss: 3.3435
# Epoch 58/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.4991 - val_loss: 3.3176
# Epoch 59/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.5204 - val_loss: 3.5242
# Epoch 60/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.4792 - val_loss: 3.4379
# Epoch 61/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.4496 - val_loss: 3.8890
# Epoch 62/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.4070 - val_loss: 3.4127
# Epoch 63/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.4135 - val_loss: 3.5759
# Epoch 64/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3937 - val_loss: 3.2677
# Epoch 65/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3938 - val_loss: 3.3162
# Epoch 66/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3674 - val_loss: 3.4165
# Epoch 67/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3248 - val_loss: 3.2384
# Epoch 68/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.2861 - val_loss: 3.3743
# Epoch 69/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3238 - val_loss: 3.2107
# Epoch 70/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.2673 - val_loss: 3.2684
# Epoch 71/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.2130 - val_loss: 3.1752
# Epoch 72/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1510 - val_loss: 3.3207
# Epoch 73/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.3065 - val_loss: 3.2268
# Epoch 74/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.2445 - val_loss: 3.1324
# Epoch 75/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.1787 - val_loss: 3.2299
# Epoch 76/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1649 - val_loss: 3.2365
# Epoch 77/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1034 - val_loss: 3.2728
# Epoch 78/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1556 - val_loss: 3.1984
# Epoch 79/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1172 - val_loss: 3.3343
# Epoch 80/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.1104 - val_loss: 3.2105
# Epoch 81/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.0883 - val_loss: 3.0730
# Epoch 82/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.0867 - val_loss: 3.1724
# Epoch 83/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.0371 - val_loss: 3.2005
# Epoch 84/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.0518 - val_loss: 3.1955
# Epoch 85/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - loss: 2.0622 - val_loss: 3.1624
# Epoch 86/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 2.0155 - val_loss: 3.3540
# Epoch 87/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9809 - val_loss: 3.2466
# Epoch 88/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 2.0022 - val_loss: 3.2134
# Epoch 89/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9279 - val_loss: 3.0650
# Epoch 90/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9285 - val_loss: 3.1666
# Epoch 91/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9242 - val_loss: 3.0686
# Epoch 92/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9143 - val_loss: 3.0399
# Epoch 93/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.9518 - val_loss: 3.1285
# Epoch 94/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8991 - val_loss: 3.0391
# Epoch 95/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8916 - val_loss: 3.1096
# Epoch 96/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8498 - val_loss: 3.1017
# Epoch 97/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8636 - val_loss: 3.0960
# Epoch 98/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8169 - val_loss: 2.9895
# Epoch 99/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8036 - val_loss: 3.0421
# Epoch 100/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8248 - val_loss: 2.9929
# Epoch 101/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8147 - val_loss: 3.1377
# Epoch 102/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.8111 - val_loss: 3.0033
# Epoch 103/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7892 - val_loss: 3.0718
# Epoch 104/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7555 - val_loss: 2.9679
# Epoch 105/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7439 - val_loss: 2.9945
# Epoch 106/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7376 - val_loss: 2.9923
# Epoch 107/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7593 - val_loss: 2.9764
# Epoch 108/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7058 - val_loss: 2.9570
# Epoch 109/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7370 - val_loss: 3.0455
# Epoch 110/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7660 - val_loss: 3.0938
# Epoch 111/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.7244 - val_loss: 3.0075
# Epoch 112/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6919 - val_loss: 2.9168
# Epoch 113/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6972 - val_loss: 2.9005
# Epoch 114/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6642 - val_loss: 2.9476
# Epoch 115/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6572 - val_loss: 2.9097
# Epoch 116/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6662 - val_loss: 2.8600
# Epoch 117/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6209 - val_loss: 2.9723
# Epoch 118/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6195 - val_loss: 2.9048
# Epoch 119/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6024 - val_loss: 2.9304
# Epoch 120/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6285 - val_loss: 2.9765
# Epoch 121/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.6018 - val_loss: 3.0301
# Epoch 122/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.5324 - val_loss: 2.8214
# Epoch 123/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.5909 - val_loss: 2.8484
# Epoch 124/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.5472 - val_loss: 2.8842
# Epoch 125/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.5461 - val_loss: 2.8339
# Epoch 126/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.5716 - val_loss: 2.8489
# Epoch 127/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.5006 - val_loss: 2.8411
# Epoch 128/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.5541 - val_loss: 2.8870
# Epoch 129/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.5476 - val_loss: 2.8053
# Epoch 130/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.5345 - val_loss: 2.7781
# Epoch 131/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.4843 - val_loss: 2.8888
# Epoch 132/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.5021 - val_loss: 2.8423
# Epoch 133/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4653 - val_loss: 2.8728
# Epoch 134/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4689 - val_loss: 2.8162
# Epoch 135/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4727 - val_loss: 2.7387
# Epoch 136/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4532 - val_loss: 2.8498
# Epoch 137/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4370 - val_loss: 2.8279
# Epoch 138/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4433 - val_loss: 2.8448
# Epoch 139/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4438 - val_loss: 2.7232
# Epoch 140/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4177 - val_loss: 2.8811
# Epoch 141/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.4199 - val_loss: 2.7387
# Epoch 142/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3798 - val_loss: 2.7806
# Epoch 143/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3995 - val_loss: 2.7916
# Epoch 144/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3782 - val_loss: 2.8160
# Epoch 145/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3935 - val_loss: 2.7564
# Epoch 146/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3681 - val_loss: 2.7895
# Epoch 147/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3820 - val_loss: 2.7379
# Epoch 148/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3555 - val_loss: 2.7444
# Epoch 149/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3390 - val_loss: 2.8232
# Epoch 150/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3344 - val_loss: 2.7828
# Epoch 151/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3375 - val_loss: 2.7905
# Epoch 152/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3951 - val_loss: 2.7261
# Epoch 153/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.2943 - val_loss: 2.6617
# Epoch 154/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3344 - val_loss: 2.6767
# Epoch 155/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.3240 - val_loss: 2.7777
# Epoch 156/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.3031 - val_loss: 2.7255
# Epoch 157/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2790 - val_loss: 2.7285
# Epoch 158/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2913 - val_loss: 2.7079
# Epoch 159/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2898 - val_loss: 2.7298
# Epoch 160/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2535 - val_loss: 2.7908
# Epoch 161/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2825 - val_loss: 2.6619
# Epoch 162/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2570 - val_loss: 2.7098
# Epoch 163/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2609 - val_loss: 2.6738
# Epoch 164/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2230 - val_loss: 2.7198
# Epoch 165/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2232 - val_loss: 2.6611
# Epoch 166/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2323 - val_loss: 2.7016
# Epoch 167/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2073 - val_loss: 2.6766
# Epoch 168/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2192 - val_loss: 2.6466
# Epoch 169/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2239 - val_loss: 2.7330
# Epoch 170/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2233 - val_loss: 2.6904
# Epoch 171/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1964 - val_loss: 2.6812
# Epoch 172/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.2086 - val_loss: 2.6613
# Epoch 173/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1992 - val_loss: 2.6579
# Epoch 174/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1832 - val_loss: 2.6235
# Epoch 175/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1431 - val_loss: 2.6433
# Epoch 176/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1756 - val_loss: 2.6658
# Epoch 177/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1694 - val_loss: 2.7324
# Epoch 178/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1550 - val_loss: 2.6431
# Epoch 179/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1464 - val_loss: 2.6963
# Epoch 180/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1856 - val_loss: 2.6173
# Epoch 181/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1529 - val_loss: 2.6063
# Epoch 182/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1725 - val_loss: 2.6663
# Epoch 183/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1903 - val_loss: 2.6685
# Epoch 184/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1224 - val_loss: 2.6222
# Epoch 185/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1396 - val_loss: 2.5936
# Epoch 186/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1035 - val_loss: 2.6044
# Epoch 187/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1307 - val_loss: 2.6211
# Epoch 188/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0998 - val_loss: 2.6319
# Epoch 189/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.1216 - val_loss: 2.6340
# Epoch 190/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0842 - val_loss: 2.5807
# Epoch 191/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.1364 - val_loss: 2.5823
# Epoch 192/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 16s 72ms/step - loss: 1.0943 - val_loss: 2.5983
# Epoch 193/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 16s 72ms/step - loss: 1.0934 - val_loss: 2.6366
# Epoch 194/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0833 - val_loss: 2.5773
# Epoch 195/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0779 - val_loss: 2.5880
# Epoch 196/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0708 - val_loss: 2.5514
# Epoch 197/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0908 - val_loss: 2.5030
# Epoch 198/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0478 - val_loss: 2.5243
# Epoch 199/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - loss: 1.0601 - val_loss: 2.5944
# Epoch 200/200
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - loss: 1.0616 - val_loss: 2.5427

# %% [markdown]
# ## Teste da rede

# %%
#Salvando o modelo treinado
model.save('Modelos/modelo_AirMLP7_1500_Reproducao.keras')

# %%
#Prevendo com o modelo
model = load_model('Modelos/modelo_AirMLP7_1500_Reproducao.keras')
y_test_pred = model.predict(X_test)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# ### Resultado do treinamento

# %%
plt.figure(figsize=(10, 6))
plt.plot(20*np.log10(history.history['loss']), linewidth=3)
plt.plot(20*np.log10(history.history['val_loss']), linewidth=3)
plt.ylabel('Magnitude (dB)', fontweight='bold')
plt.xlabel('Épocas', fontweight='bold')
plt.legend(['Treinamento', 'Teste'], loc='upper right')
plt.grid()

# %% [markdown]
# ### Resultado da estimação

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test_pred[:200], 'r-', label='Valores Previstos', linewidth=3)
plt.plot(y_test.values[:200], 'b--', label='Valores Reais', linewidth=3)
plt.xlabel('Amostras', fontweight='bold')
plt.ylabel('PM2.5 [μg/m³]', fontweight='bold')
plt.grid()
plt.legend()

# %% [markdown]
# ### Rersultado das métricas

# %%
mae = mean_absolute_error(y_test.values, y_test_pred)
rmse = root_mean_squared_error(y_test.values, y_test_pred)
r2 = r2_score(y_test.values, y_test_pred)
print(f'MAE: {mae:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'R2: {r2:.4f}')
# Out:
# MAE: 2.5427
# RMSE: 4.4662
# R2: 0.9200
